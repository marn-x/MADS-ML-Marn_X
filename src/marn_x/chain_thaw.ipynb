# %%
from typing import cast

from mads_datasets.settings import ImgDatasetSettings, FileTypes
from mads_datasets.factories.torchfactories import ImgDataset
from mads_datasets.base import AbstractDatasetFactory, DatasetProtocol
from mads_datasets.datatools import iter_valid_paths
from pydantic import HttpUrl
from pathlib import Path

from torch import nn

from torchvision import transforms
import torch

import hashlib
import random
from abc import ABC, abstractmethod
from pathlib import Path
from typing import (
    Any,
    Callable,
    Generic,
    Iterator,
    List,
    Mapping,
    Optional,
    Protocol,
    Sequence,
    Tuple,
    TypeVar,
)

import numpy as np
from loguru import logger

from mads_datasets.datatools import create_headers, get_file
from mads_datasets.settings import DatasetSettings, SecureDatasetSettings

if torch.backends.mps.is_available() and torch.backends.mps.is_built():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = "cpu"
    logger.warning("This model will take 15-20 minutes on CPU. Consider using accelaration, eg with google colab (see button on top of the page)")
logger.info(f"Using {device}")

eurosatsettings = ImgDatasetSettings(
    dataset_url=cast(
        HttpUrl,
        "https://huggingface.co/datasets/torchgeo/eurosat/resolve/c877bcd43f099cd0196738f714544e355477f3fd/EuroSAT.zip",
    ),
    filename=Path("EuroSAT_RGB.zip"),
    name="EuroSAT_RGB",
    unzip=True,
    formats=[FileTypes.JPG],
    trainfrac=0.8,
    img_size=(64, 64),
    digest="c8fa014336c82ac7804f0398fcb19387",
)

data_transforms = transforms.Compose([
    # transforms.RandomResizedCrop(224),
    # transforms.RandomHorizontalFlip(),
    # transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

class EurosatDatasetFactory(AbstractDatasetFactory[ImgDatasetSettings]):
    def create_dataset(
        self, *args: Any, **kwargs: Any
    ) -> Mapping[str, DatasetProtocol]:
        self.download_data()
        formats = self._settings.formats
        paths_, class_names = iter_valid_paths(
            self.subfolder / "2750", formats=formats 
        )
        paths = [*paths_]
        random.shuffle(paths)
        trainidx = int(len(paths) * self._settings.trainfrac)
        train = paths[:trainidx]
        valid = paths[trainidx:]
        traindataset = ImgDataset(train, class_names, img_size=self._settings.img_size)
        validdataset = ImgDataset(valid, class_names, img_size=self._settings.img_size)
        return {"train": traindataset, "valid": validdataset}

eurosatfactory = EurosatDatasetFactory(eurosatsettings, datadir=Path.home() / ".cache/mads_datasets")

class AugmentPreprocessor():
    def __init__(self, transform):
        self.transform = transform
    def __call__(self, batch: list[tuple]) -> tuple[torch.Tensor, torch.Tensor]:
        X, y = zip(*batch)
        X = [self.transform(x) for x in X]
        return torch.stack(X), torch.stack(y)
    
streamers = eurosatfactory.create_datastreamer(batchsize=32)

trainprocessor= AugmentPreprocessor(data_transforms)
# validprocessor = AugmentPreprocessor(data_transforms["val"])

train = streamers["train"]
valid = streamers["valid"]
train.preprocessor = trainprocessor
valid.preprocessor = trainprocessor
trainstreamer = train.stream()
validstreamer = valid.stream()

import torchvision
from torchvision.models import resnet18, ResNet18_Weights
resnet = torchvision.models.resnet18(weights=ResNet18_Weights.DEFAULT)
# Out:
# 2025-05-26 17:56:23.234 | INFO     | __main__:<module>:46 - Using cuda
# 2025-05-26 17:56:23.235 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /home/marnix/.cache/mads_datasets/EuroSAT_RGB

# %%
image_datasets = {"train" : streamers["train"].dataset,
                    "val" : streamers["valid"].dataset}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = streamers["train"].dataset.class_names
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                                shuffle=True, num_workers=4)
                for x in ['train', 'val']}

# %%
from pathlib import Path
import requests
import zipfile
from loguru import logger

from torchvision import datasets

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory

# %%
def train(model, dataloader, lossfn, optimizer, device):
    model.train()
    train_loss: float = 0.0
    train_acc: float = 0.0
    for x, y in dataloader:
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad()
        yhat = model(x)
        loss = lossfn(yhat, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, acc = torch.max(yhat, 1)
        train_acc += torch.sum(acc == y.data)
    return train_loss, train_acc

def test(model, dataloader, lossfn, optimizer, scheduler, device):
    model.eval()
    test_loss: float = 0.0
    test_acc: float = 0.0
    for x, y in dataloader:
        x = x.to(device)
        y = y.to(device)
        yhat = model(x)
        loss = lossfn(yhat, y)
        test_loss += loss.item()
        _, acc = torch.max(yhat, 1)
        test_acc += torch.sum(acc == y.data)
    scheduler.step(test_loss)
    return test_loss, test_acc


def train_model(model, lossfn, optimizer, scheduler, num_epochs, dataloaders, dataset_sizes, device):
    with TemporaryDirectory() as tempdir:
        best_model_params_path = Path(tempdir) / 'best_model_params.pt'
        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0 # we will only save the best model

        for epoch in range(num_epochs):
            logger.info(f'Epoch {epoch}/{num_epochs - 1}')
            train_loss, train_acc = train(model, dataloaders['train'], lossfn, optimizer, device)
            train_loss = train_loss / dataset_sizes['train']
            train_acc = train_acc / dataset_sizes['train']
            logger.info(f'Train Loss: {train_loss:.4f} Accuracy: {train_acc:.4f}')
            test_loss, test_acc = test(model, dataloaders['val'], lossfn, optimizer, scheduler, device)
            test_loss = test_loss / dataset_sizes['val']
            test_acc = test_acc / dataset_sizes['val']
            logger.info(f'Test Loss: {test_loss:.4f} Accuracy: {test_acc:.4f}')
            if test_acc > best_acc:
                    best_acc = test_acc
                    logger.info(f"New best accuracy: {best_acc:.4f}, saving model")
                    torch.save(model.state_dict(), best_model_params_path)
        model.load_state_dict(torch.load(best_model_params_path))
        return model
    
def visualize_model(model, num_images=6):
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                title = class_names[preds[j]]
                ax.set_title(f'predicted: {title}')
                imshow(inputs.cpu().data[j], title)

                if images_so_far == num_images:
                    return

# %%
model = models.resnet18(weights='IMAGENET1K_V1')
num_ftrs = model.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model.fc = nn.Linear(num_ftrs, 10)

model = model.to(device)
lossfn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# Decay LR by a factor of 0.1 every 7 epochs

settings = {'step_size' : 7, 'gamma' : 0.1}
scheduler = lr_scheduler.StepLR(optimizer, **settings)

# %%
dataloaders["train"]

# %%
layer_groups = [
    [],  # Custom head
    ['layer4'],  # Last ResNet block
    ['layer3'],  # Third ResNet block
    ['layer2'],  # Second ResNet block
    ['layer1', 'conv1', 'bn1']  # First layers
]

# %%
for param in model.parameters():
    param.requires_grad = False

# %%
for param in model.fc.parameters():
    param.requires_grad = True

# %%
import time
def time_convert(sec):
  mins = sec // 60
  sec = sec % 60
  hours = mins // 60
  mins = mins % 60
  return "{0}:{1}:{2}".format(int(hours),int(mins),sec)

# %%
for stage, layers_to_unfreeze in enumerate(layer_groups):
    print(f"\nStage {stage + 1}: Unfreezing {layers_to_unfreeze}")
    
    # Unfreeze specified layers
    for layer_name in layers_to_unfreeze:
        layer = getattr(model, layer_name)
    for param in layer.parameters():
        param.requires_grad = True
    
    # Update optimizer to include new parameters
    optimizer = torch.optim.SGD(
        filter(lambda p: p.requires_grad, model.parameters()), 
        lr=1e-3 * (0.5 ** stage)  # Decay learning rate
    )

    start = time.time()
    epochs = 5
    model = train_model(
        model = model,
        lossfn = lossfn,
        optimizer = optimizer,
        scheduler = scheduler,
        num_epochs = epochs,
        dataloaders = dataloaders,
        dataset_sizes = dataset_sizes,
        device = device,
    )
    end = time.time()
    logger.success(f"Done! layer {layers_to_unfreeze} trained for {epochs} epochs in {time_convert(end - start)}")
# Out:
# 2025-05-26 18:04:42.211 | INFO     | __main__:train_model:41 - Epoch 0/4
# Stage 1: Unfreezing []
# 2025-05-26 18:04:55.582 | INFO     | __main__:train_model:45 - Train Loss: 0.3280 Accuracy: 0.5521
# /home/marnix/SynologyDrive/MADS-ML-Marn_X/.venv/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:182: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# /home/marnix/SynologyDrive/MADS-ML-Marn_X/.venv/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:198: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# 2025-05-26 18:04:58.399 | INFO     | __main__:train_model:49 - Test Loss: 0.2118 Accuracy: 0.7522
# 2025-05-26 18:04:58.400 | INFO     | __main__:train_model:52 - New best accuracy: 0.7522, saving model
# 2025-05-26 18:04:58.431 | INFO     | __main__:train_model:41 - Epoch 1/4
# 2025-05-26 18:05:10.969 | INFO     | __main__:train_model:45 - Train Loss: 0.2725 Accuracy: 0.6286
# 2025-05-26 18:05:13.685 | INFO     | __main__:train_model:49 - Test Loss: 0.1966 Accuracy: 0.7702
# 2025-05-26 18:05:13.686 | INFO     | __main__:train_model:52 - New best accuracy: 0.7702, saving model
# 2025-05-26 18:05:13.716 | INFO     | __main__:train_model:41 - Epoch 2/4
# 2025-05-26 18:05:25.868 | INFO     | __main__:train_model:45 - Train Loss: 0.2583 Accuracy: 0.6515
# 2025-05-26 18:05:28.793 | INFO     | __main__:train_model:49 - Test Loss: 0.2110 Accuracy: 0.7656
# 2025-05-26 18:05:28.794 | INFO     | __main__:train_model:41 - Epoch 3/4
# 2025-05-26 18:05:41.724 | INFO     | __main__:train_model:45 - Train Loss: 0.2586 Accuracy: 0.6545
# 2025-05-26 18:05:44.323 | INFO     | __main__:train_model:49 - Test Loss: 0.2099 Accuracy: 0.7422
# 2025-05-26 18:05:44.324 | INFO     | __main__:train_model:41 - Epoch 4/4
# 2025-05-26 18:05:54.408 | INFO     | __main__:train_model:45 - Train Loss: 0.2548 Accuracy: 0.6557
# 2025-05-26 18:05:57.111 | INFO     | __main__:train_model:49 - Test Loss: 0.2082 Accuracy: 0.7274
# 2025-05-26 18:05:57.136 | SUCCESS  | __main__:<module>:30 - Done! layer [] trained for 5 epochs in 0:1:14.958922386169434
# 2025-05-26 18:05:57.166 | INFO     | __main__:train_model:41 - Epoch 0/4
# Stage 2: Unfreezing ['layer4']
# 2025-05-26 18:06:19.756 | INFO     | __main__:train_model:45 - Train Loss: 0.2208 Accuracy: 0.7028
# 2025-05-26 18:06:22.631 | INFO     | __main__:train_model:49 - Test Loss: 0.2029 Accuracy: 0.7622
# 2025-05-26 18:06:22.632 | INFO     | __main__:train_model:52 - New best accuracy: 0.7622, saving model
# 2025-05-26 18:06:22.664 | INFO     | __main__:train_model:41 - Epoch 1/4
# 2025-05-26 18:06:44.503 | INFO     | __main__:train_model:45 - Train Loss: 0.1795 Accuracy: 0.7584
# 2025-05-26 18:06:47.363 | INFO     | __main__:train_model:49 - Test Loss: 0.1833 Accuracy: 0.7698
# 2025-05-26 18:06:47.364 | INFO     | __main__:train_model:52 - New best accuracy: 0.7698, saving model
# 2025-05-26 18:06:47.397 | INFO     | __main__:train_model:41 - Epoch 2/4
# 2025-05-26 18:07:10.244 | INFO     | __main__:train_model:45 - Train Loss: 0.1627 Accuracy: 0.7871
# 2025-05-26 18:07:12.927 | INFO     | __main__:train_model:49 - Test Loss: 0.1447 Accuracy: 0.8172
# 2025-05-26 18:07:12.927 | INFO     | __main__:train_model:52 - New best accuracy: 0.8172, saving model
# 2025-05-26 18:07:12.957 | INFO     | __main__:train_model:41 - Epoch 3/4
# 2025-05-26 18:07:35.042 | INFO     | __main__:train_model:45 - Train Loss: 0.1492 Accuracy: 0.8062
# 2025-05-26 18:07:37.791 | INFO     | __main__:train_model:49 - Test Loss: 0.1266 Accuracy: 0.8430
# 2025-05-26 18:07:37.792 | INFO     | __main__:train_model:52 - New best accuracy: 0.8430, saving model
# 2025-05-26 18:07:37.822 | INFO     | __main__:train_model:41 - Epoch 4/4
# 2025-05-26 18:08:00.339 | INFO     | __main__:train_model:45 - Train Loss: 0.1393 Accuracy: 0.8175
# 2025-05-26 18:08:03.143 | INFO     | __main__:train_model:49 - Test Loss: 0.1384 Accuracy: 0.8246
# 2025-05-26 18:08:03.166 | SUCCESS  | __main__:<module>:30 - Done! layer ['layer4'] trained for 5 epochs in 0:2:6.029709815979004
# 2025-05-26 18:08:03.194 | INFO     | __main__:train_model:41 - Epoch 0/4
# Stage 3: Unfreezing ['layer3']
# 2025-05-26 18:08:29.423 | INFO     | __main__:train_model:45 - Train Loss: 0.1343 Accuracy: 0.8226
# 2025-05-26 18:08:32.251 | INFO     | __main__:train_model:49 - Test Loss: 0.1151 Accuracy: 0.8661
# 2025-05-26 18:08:32.252 | INFO     | __main__:train_model:52 - New best accuracy: 0.8661, saving model
# 2025-05-26 18:08:32.282 | INFO     | __main__:train_model:41 - Epoch 1/4
# 2025-05-26 18:08:58.761 | INFO     | __main__:train_model:45 - Train Loss: 0.1241 Accuracy: 0.8410
# 2025-05-26 18:09:01.611 | INFO     | __main__:train_model:49 - Test Loss: 0.1153 Accuracy: 0.8528
# 2025-05-26 18:09:01.612 | INFO     | __main__:train_model:41 - Epoch 2/4
# 2025-05-26 18:09:28.575 | INFO     | __main__:train_model:45 - Train Loss: 0.1136 Accuracy: 0.8520
# 2025-05-26 18:09:31.731 | INFO     | __main__:train_model:49 - Test Loss: 0.0880 Accuracy: 0.8911
# 2025-05-26 18:09:31.732 | INFO     | __main__:train_model:52 - New best accuracy: 0.8911, saving model
# 2025-05-26 18:09:31.764 | INFO     | __main__:train_model:41 - Epoch 3/4
# 2025-05-26 18:09:58.325 | INFO     | __main__:train_model:45 - Train Loss: 0.1105 Accuracy: 0.8559
# 2025-05-26 18:10:01.288 | INFO     | __main__:train_model:49 - Test Loss: 0.0751 Accuracy: 0.9067
# 2025-05-26 18:10:01.289 | INFO     | __main__:train_model:52 - New best accuracy: 0.9067, saving model
# 2025-05-26 18:10:01.320 | INFO     | __main__:train_model:41 - Epoch 4/4
# 2025-05-26 18:10:27.860 | INFO     | __main__:train_model:45 - Train Loss: 0.1049 Accuracy: 0.8687
# 2025-05-26 18:10:30.781 | INFO     | __main__:train_model:49 - Test Loss: 0.0714 Accuracy: 0.9131
# 2025-05-26 18:10:30.782 | INFO     | __main__:train_model:52 - New best accuracy: 0.9131, saving model
# 2025-05-26 18:10:30.837 | SUCCESS  | __main__:<module>:30 - Done! layer ['layer3'] trained for 5 epochs in 0:2:27.66959023475647
# 2025-05-26 18:10:30.867 | INFO     | __main__:train_model:41 - Epoch 0/4
# Stage 4: Unfreezing ['layer2']
# 2025-05-26 18:10:59.684 | INFO     | __main__:train_model:45 - Train Loss: 0.1010 Accuracy: 0.8705
# 2025-05-26 18:11:02.552 | INFO     | __main__:train_model:49 - Test Loss: 0.0738 Accuracy: 0.9057
# 2025-05-26 18:11:02.553 | INFO     | __main__:train_model:52 - New best accuracy: 0.9057, saving model
# 2025-05-26 18:11:02.584 | INFO     | __main__:train_model:41 - Epoch 1/4
# 2025-05-26 18:11:30.528 | INFO     | __main__:train_model:45 - Train Loss: 0.0963 Accuracy: 0.8759
# 2025-05-26 18:11:33.646 | INFO     | __main__:train_model:49 - Test Loss: 0.0736 Accuracy: 0.9122
# 2025-05-26 18:11:33.647 | INFO     | __main__:train_model:52 - New best accuracy: 0.9122, saving model
# 2025-05-26 18:11:33.677 | INFO     | __main__:train_model:41 - Epoch 2/4
# 2025-05-26 18:12:01.927 | INFO     | __main__:train_model:45 - Train Loss: 0.0911 Accuracy: 0.8857
# 2025-05-26 18:12:04.650 | INFO     | __main__:train_model:49 - Test Loss: 0.0676 Accuracy: 0.9137
# 2025-05-26 18:12:04.651 | INFO     | __main__:train_model:52 - New best accuracy: 0.9137, saving model
# 2025-05-26 18:12:04.682 | INFO     | __main__:train_model:41 - Epoch 3/4
# 2025-05-26 18:12:32.659 | INFO     | __main__:train_model:45 - Train Loss: 0.0881 Accuracy: 0.8863
# 2025-05-26 18:12:35.604 | INFO     | __main__:train_model:49 - Test Loss: 0.0604 Accuracy: 0.9233
# 2025-05-26 18:12:35.605 | INFO     | __main__:train_model:52 - New best accuracy: 0.9233, saving model
# 2025-05-26 18:12:35.636 | INFO     | __main__:train_model:41 - Epoch 4/4
# 2025-05-26 18:13:03.550 | INFO     | __main__:train_model:45 - Train Loss: 0.0866 Accuracy: 0.8918
# 2025-05-26 18:13:06.508 | INFO     | __main__:train_model:49 - Test Loss: 0.0729 Accuracy: 0.9089
# 2025-05-26 18:13:06.531 | SUCCESS  | __main__:<module>:30 - Done! layer ['layer2'] trained for 5 epochs in 0:2:35.693625688552856
# 2025-05-26 18:13:06.559 | INFO     | __main__:train_model:41 - Epoch 0/4
# Stage 5: Unfreezing ['layer1', 'conv1', 'bn1']
# 2025-05-26 18:13:36.496 | INFO     | __main__:train_model:45 - Train Loss: 0.0843 Accuracy: 0.8932
# 2025-05-26 18:13:39.518 | INFO     | __main__:train_model:49 - Test Loss: 0.0588 Accuracy: 0.9244
# 2025-05-26 18:13:39.519 | INFO     | __main__:train_model:52 - New best accuracy: 0.9244, saving model
# 2025-05-26 18:13:39.548 | INFO     | __main__:train_model:41 - Epoch 1/4
# 2025-05-26 18:14:09.222 | INFO     | __main__:train_model:45 - Train Loss: 0.0822 Accuracy: 0.8948
# 2025-05-26 18:14:12.383 | INFO     | __main__:train_model:49 - Test Loss: 0.0708 Accuracy: 0.9157
# 2025-05-26 18:14:12.384 | INFO     | __main__:train_model:41 - Epoch 2/4
# 2025-05-26 18:14:43.194 | INFO     | __main__:train_model:45 - Train Loss: 0.0838 Accuracy: 0.8961
# 2025-05-26 18:14:46.238 | INFO     | __main__:train_model:49 - Test Loss: 0.0683 Accuracy: 0.9156
# 2025-05-26 18:14:46.239 | INFO     | __main__:train_model:41 - Epoch 3/4
# 2025-05-26 18:15:16.391 | INFO     | __main__:train_model:45 - Train Loss: 0.0795 Accuracy: 0.9002
# 2025-05-26 18:15:19.496 | INFO     | __main__:train_model:49 - Test Loss: 0.0653 Accuracy: 0.9196
# 2025-05-26 18:15:19.497 | INFO     | __main__:train_model:41 - Epoch 4/4
# 2025-05-26 18:15:51.421 | INFO     | __main__:train_model:45 - Train Loss: 0.0771 Accuracy: 0.9022
# 2025-05-26 18:15:54.371 | INFO     | __main__:train_model:49 - Test Loss: 0.0696 Accuracy: 0.9165
# 2025-05-26 18:15:54.394 | SUCCESS  | __main__:<module>:30 - Done! layer ['layer1', 'conv1', 'bn1'] trained for 5 epochs in 0:2:47.86199474334717

# %%
model = models.resnet18(weights='IMAGENET1K_V1')
num_ftrs = model.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model.fc = nn.Linear(num_ftrs, 10)

model = model.to(device)
lossfn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# Decay LR by a factor of 0.1 every 7 epochs

settings = {'step_size' : 7, 'gamma' : 0.1}
scheduler = lr_scheduler.StepLR(optimizer, **settings)

# %%
for param in model.parameters():
    param.requires_grad = False

# %%
for param in model.fc.parameters():
    param.requires_grad = True

# %%
start = time.time()
epochs = 25
model = train_model(
    model = model,
    lossfn = lossfn,
    optimizer = optimizer,
    scheduler = scheduler,
    num_epochs = epochs,
    dataloaders = dataloaders,
    dataset_sizes = dataset_sizes,
    device = device,
)
end = time.time()
logger.success(f"Done! layer {layers_to_unfreeze} trained for {epochs} epochs in {time_convert(end - start)}")
# Out:
# 2025-05-26 18:30:21.619 | INFO     | __main__:train_model:41 - Epoch 0/24
# 2025-05-26 18:30:35.240 | INFO     | __main__:train_model:45 - Train Loss: 0.3678 Accuracy: 0.5613
# /home/marnix/SynologyDrive/MADS-ML-Marn_X/.venv/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:198: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# 2025-05-26 18:30:37.991 | INFO     | __main__:train_model:49 - Test Loss: 0.3418 Accuracy: 0.6972
# 2025-05-26 18:30:37.991 | INFO     | __main__:train_model:52 - New best accuracy: 0.6972, saving model
# 2025-05-26 18:30:38.022 | INFO     | __main__:train_model:41 - Epoch 1/24
# 2025-05-26 18:30:50.323 | INFO     | __main__:train_model:45 - Train Loss: 0.3397 Accuracy: 0.5957
# 2025-05-26 18:30:53.058 | INFO     | __main__:train_model:49 - Test Loss: 0.3850 Accuracy: 0.6654
# 2025-05-26 18:30:53.059 | INFO     | __main__:train_model:41 - Epoch 2/24
# 2025-05-26 18:31:05.996 | INFO     | __main__:train_model:45 - Train Loss: 0.3415 Accuracy: 0.5948
# 2025-05-26 18:31:08.892 | INFO     | __main__:train_model:49 - Test Loss: 0.3273 Accuracy: 0.7019
# 2025-05-26 18:31:08.892 | INFO     | __main__:train_model:52 - New best accuracy: 0.7019, saving model
# 2025-05-26 18:31:08.924 | INFO     | __main__:train_model:41 - Epoch 3/24
# 2025-05-26 18:31:22.041 | INFO     | __main__:train_model:45 - Train Loss: 0.3348 Accuracy: 0.6023
# 2025-05-26 18:31:25.038 | INFO     | __main__:train_model:49 - Test Loss: 0.3340 Accuracy: 0.6715
# 2025-05-26 18:31:25.038 | INFO     | __main__:train_model:41 - Epoch 4/24
# 2025-05-26 18:31:37.717 | INFO     | __main__:train_model:45 - Train Loss: 0.3402 Accuracy: 0.5946
# 2025-05-26 18:31:40.509 | INFO     | __main__:train_model:49 - Test Loss: 0.3706 Accuracy: 0.6724
# 2025-05-26 18:31:40.509 | INFO     | __main__:train_model:41 - Epoch 5/24
# 2025-05-26 18:31:52.941 | INFO     | __main__:train_model:45 - Train Loss: 0.3432 Accuracy: 0.5938
# 2025-05-26 18:31:55.701 | INFO     | __main__:train_model:49 - Test Loss: 0.3440 Accuracy: 0.6863
# 2025-05-26 18:31:55.701 | INFO     | __main__:train_model:41 - Epoch 6/24
# 2025-05-26 18:32:08.356 | INFO     | __main__:train_model:45 - Train Loss: 0.3358 Accuracy: 0.5953
# 2025-05-26 18:32:11.077 | INFO     | __main__:train_model:49 - Test Loss: 0.3359 Accuracy: 0.6809
# 2025-05-26 18:32:11.081 | INFO     | __main__:train_model:41 - Epoch 7/24
# 2025-05-26 18:32:23.249 | INFO     | __main__:train_model:45 - Train Loss: 0.3392 Accuracy: 0.5954
# 2025-05-26 18:32:26.086 | INFO     | __main__:train_model:49 - Test Loss: 0.3307 Accuracy: 0.6950
# 2025-05-26 18:32:26.086 | INFO     | __main__:train_model:41 - Epoch 8/24
# 2025-05-26 18:32:38.317 | INFO     | __main__:train_model:45 - Train Loss: 0.3435 Accuracy: 0.5945
# 2025-05-26 18:32:41.055 | INFO     | __main__:train_model:49 - Test Loss: 0.3402 Accuracy: 0.6776
# 2025-05-26 18:32:41.056 | INFO     | __main__:train_model:41 - Epoch 9/24
# 2025-05-26 18:32:53.205 | INFO     | __main__:train_model:45 - Train Loss: 0.3380 Accuracy: 0.5997
# 2025-05-26 18:32:55.952 | INFO     | __main__:train_model:49 - Test Loss: 0.3336 Accuracy: 0.6785
# 2025-05-26 18:32:55.953 | INFO     | __main__:train_model:41 - Epoch 10/24
# 2025-05-26 18:33:08.625 | INFO     | __main__:train_model:45 - Train Loss: 0.3410 Accuracy: 0.5906
# 2025-05-26 18:33:11.351 | INFO     | __main__:train_model:49 - Test Loss: 0.3840 Accuracy: 0.6678
# 2025-05-26 18:33:11.352 | INFO     | __main__:train_model:41 - Epoch 11/24
# 2025-05-26 18:33:23.440 | INFO     | __main__:train_model:45 - Train Loss: 0.3423 Accuracy: 0.5948
# 2025-05-26 18:33:26.364 | INFO     | __main__:train_model:49 - Test Loss: 0.3682 Accuracy: 0.6624
# 2025-05-26 18:33:26.365 | INFO     | __main__:train_model:41 - Epoch 12/24
# 2025-05-26 18:33:40.312 | INFO     | __main__:train_model:45 - Train Loss: 0.3454 Accuracy: 0.5882
# 2025-05-26 18:33:43.097 | INFO     | __main__:train_model:49 - Test Loss: 0.3232 Accuracy: 0.6991
# 2025-05-26 18:33:43.098 | INFO     | __main__:train_model:41 - Epoch 13/24
# 2025-05-26 18:33:55.639 | INFO     | __main__:train_model:45 - Train Loss: 0.3419 Accuracy: 0.5989
# 2025-05-26 18:33:58.442 | INFO     | __main__:train_model:49 - Test Loss: 0.3526 Accuracy: 0.6698
# 2025-05-26 18:33:58.443 | INFO     | __main__:train_model:41 - Epoch 14/24
# 2025-05-26 18:34:11.772 | INFO     | __main__:train_model:45 - Train Loss: 0.3388 Accuracy: 0.5935
# 2025-05-26 18:34:14.550 | INFO     | __main__:train_model:49 - Test Loss: 0.3357 Accuracy: 0.6935
# 2025-05-26 18:34:14.550 | INFO     | __main__:train_model:41 - Epoch 15/24
# 2025-05-26 18:34:28.108 | INFO     | __main__:train_model:45 - Train Loss: 0.3366 Accuracy: 0.5952
# 2025-05-26 18:34:30.897 | INFO     | __main__:train_model:49 - Test Loss: 0.3458 Accuracy: 0.6785
# 2025-05-26 18:34:30.897 | INFO     | __main__:train_model:41 - Epoch 16/24
# 2025-05-26 18:34:43.804 | INFO     | __main__:train_model:45 - Train Loss: 0.3423 Accuracy: 0.5935
# 2025-05-26 18:34:46.613 | INFO     | __main__:train_model:49 - Test Loss: 0.3174 Accuracy: 0.7037
# 2025-05-26 18:34:46.614 | INFO     | __main__:train_model:52 - New best accuracy: 0.7037, saving model
# 2025-05-26 18:34:46.645 | INFO     | __main__:train_model:41 - Epoch 17/24
# 2025-05-26 18:34:59.588 | INFO     | __main__:train_model:45 - Train Loss: 0.3413 Accuracy: 0.5951
# 2025-05-26 18:35:02.415 | INFO     | __main__:train_model:49 - Test Loss: 0.3569 Accuracy: 0.6896
# 2025-05-26 18:35:02.415 | INFO     | __main__:train_model:41 - Epoch 18/24
# 2025-05-26 18:35:16.813 | INFO     | __main__:train_model:45 - Train Loss: 0.3407 Accuracy: 0.5931
# 2025-05-26 18:35:19.876 | INFO     | __main__:train_model:49 - Test Loss: 0.3355 Accuracy: 0.6935
# 2025-05-26 18:35:19.877 | INFO     | __main__:train_model:41 - Epoch 19/24
# 2025-05-26 18:35:34.845 | INFO     | __main__:train_model:45 - Train Loss: 0.3440 Accuracy: 0.5941
# 2025-05-26 18:35:37.922 | INFO     | __main__:train_model:49 - Test Loss: 0.3400 Accuracy: 0.6694
# 2025-05-26 18:35:37.923 | INFO     | __main__:train_model:41 - Epoch 20/24
# 2025-05-26 18:35:53.136 | INFO     | __main__:train_model:45 - Train Loss: 0.3418 Accuracy: 0.5966
# 2025-05-26 18:35:56.164 | INFO     | __main__:train_model:49 - Test Loss: 0.3381 Accuracy: 0.6763
# 2025-05-26 18:35:56.165 | INFO     | __main__:train_model:41 - Epoch 21/24
# 2025-05-26 18:36:10.706 | INFO     | __main__:train_model:45 - Train Loss: 0.3427 Accuracy: 0.5931
# 2025-05-26 18:36:13.674 | INFO     | __main__:train_model:49 - Test Loss: 0.3487 Accuracy: 0.6785
# 2025-05-26 18:36:13.675 | INFO     | __main__:train_model:41 - Epoch 22/24
# 2025-05-26 18:36:27.900 | INFO     | __main__:train_model:45 - Train Loss: 0.3375 Accuracy: 0.5945
# 2025-05-26 18:36:30.646 | INFO     | __main__:train_model:49 - Test Loss: 0.3299 Accuracy: 0.6924
# 2025-05-26 18:36:30.647 | INFO     | __main__:train_model:41 - Epoch 23/24
# 2025-05-26 18:36:44.289 | INFO     | __main__:train_model:45 - Train Loss: 0.3414 Accuracy: 0.5924
# 2025-05-26 18:36:47.050 | INFO     | __main__:train_model:49 - Test Loss: 0.3444 Accuracy: 0.6770
# 2025-05-26 18:36:47.051 | INFO     | __main__:train_model:41 - Epoch 24/24
# 2025-05-26 18:36:59.887 | INFO     | __main__:train_model:45 - Train Loss: 0.3328 Accuracy: 0.6021
# 2025-05-26 18:37:02.731 | INFO     | __main__:train_model:49 - Test Loss: 0.3749 Accuracy: 0.6722
# 2025-05-26 18:37:02.760 | SUCCESS  | __main__:<module>:14 - Done! layer ['layer1', 'conv1', 'bn1'] trained for 25 epochs in 0:6:41.1687798500061

# %%
model = models.resnet18(weights='IMAGENET1K_V1')
num_ftrs = model.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to ``nn.Linear(num_ftrs, len(class_names))``.
model.fc = nn.Linear(num_ftrs, 10)

model = model.to(device)
lossfn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# Decay LR by a factor of 0.1 every 7 epochs

settings = {'step_size' : 7, 'gamma' : 0.1}
scheduler = lr_scheduler.StepLR(optimizer, **settings)

# %%
for param in model.parameters():
    param.requires_grad = True
for param in model.fc.parameters():
    param.requires_grad = True

# %%
start = time.time()
epochs = 25
model = train_model(
    model = model,
    lossfn = lossfn,
    optimizer = optimizer,
    scheduler = scheduler,
    num_epochs = epochs,
    dataloaders = dataloaders,
    dataset_sizes = dataset_sizes,
    device = device,
)
end = time.time()
logger.success(f"Done! layer {layers_to_unfreeze} trained for {epochs} epochs in {time_convert(end - start)}")
# Out:
# 2025-05-26 18:37:30.035 | INFO     | __main__:train_model:41 - Epoch 0/24
# 2025-05-26 18:38:11.339 | INFO     | __main__:train_model:45 - Train Loss: 0.2396 Accuracy: 0.7038
# /home/marnix/SynologyDrive/MADS-ML-Marn_X/.venv/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:198: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# 2025-05-26 18:38:14.824 | INFO     | __main__:train_model:49 - Test Loss: 0.0891 Accuracy: 0.8978
# 2025-05-26 18:38:14.825 | INFO     | __main__:train_model:52 - New best accuracy: 0.8978, saving model
# 2025-05-26 18:38:14.858 | INFO     | __main__:train_model:41 - Epoch 1/24
# 2025-05-26 18:38:54.921 | INFO     | __main__:train_model:45 - Train Loss: 0.1343 Accuracy: 0.8315
# 2025-05-26 18:38:58.017 | INFO     | __main__:train_model:49 - Test Loss: 0.0840 Accuracy: 0.8987
# 2025-05-26 18:38:58.017 | INFO     | __main__:train_model:52 - New best accuracy: 0.8987, saving model
# 2025-05-26 18:38:58.055 | INFO     | __main__:train_model:41 - Epoch 2/24
# 2025-05-26 18:39:37.863 | INFO     | __main__:train_model:45 - Train Loss: 0.1359 Accuracy: 0.8283
# 2025-05-26 18:39:41.162 | INFO     | __main__:train_model:49 - Test Loss: 0.0753 Accuracy: 0.9083
# 2025-05-26 18:39:41.163 | INFO     | __main__:train_model:52 - New best accuracy: 0.9083, saving model
# 2025-05-26 18:39:41.194 | INFO     | __main__:train_model:41 - Epoch 3/24
# 2025-05-26 18:40:20.506 | INFO     | __main__:train_model:45 - Train Loss: 0.1365 Accuracy: 0.8295
# 2025-05-26 18:40:23.531 | INFO     | __main__:train_model:49 - Test Loss: 0.0735 Accuracy: 0.9081
# 2025-05-26 18:40:23.532 | INFO     | __main__:train_model:41 - Epoch 4/24
# 2025-05-26 18:41:02.889 | INFO     | __main__:train_model:45 - Train Loss: 0.1362 Accuracy: 0.8313
# 2025-05-26 18:41:06.035 | INFO     | __main__:train_model:49 - Test Loss: 0.0949 Accuracy: 0.8894
# 2025-05-26 18:41:06.036 | INFO     | __main__:train_model:41 - Epoch 5/24
# 2025-05-26 18:41:45.704 | INFO     | __main__:train_model:45 - Train Loss: 0.1344 Accuracy: 0.8313
# 2025-05-26 18:41:48.646 | INFO     | __main__:train_model:49 - Test Loss: 0.0771 Accuracy: 0.9065
# 2025-05-26 18:41:48.646 | INFO     | __main__:train_model:41 - Epoch 6/24
# 2025-05-26 18:42:28.222 | INFO     | __main__:train_model:45 - Train Loss: 0.1385 Accuracy: 0.8277
# 2025-05-26 18:42:31.144 | INFO     | __main__:train_model:49 - Test Loss: 0.0805 Accuracy: 0.9035
# 2025-05-26 18:42:31.144 | INFO     | __main__:train_model:41 - Epoch 7/24
# 2025-05-26 18:43:10.729 | INFO     | __main__:train_model:45 - Train Loss: 0.1384 Accuracy: 0.8281
# 2025-05-26 18:43:13.835 | INFO     | __main__:train_model:49 - Test Loss: 0.0820 Accuracy: 0.9024
# 2025-05-26 18:43:13.836 | INFO     | __main__:train_model:41 - Epoch 8/24
# 2025-05-26 18:43:53.232 | INFO     | __main__:train_model:45 - Train Loss: 0.1360 Accuracy: 0.8328
# 2025-05-26 18:43:56.129 | INFO     | __main__:train_model:49 - Test Loss: 0.0837 Accuracy: 0.9017
# 2025-05-26 18:43:56.133 | INFO     | __main__:train_model:41 - Epoch 9/24
# 2025-05-26 18:44:35.418 | INFO     | __main__:train_model:45 - Train Loss: 0.1357 Accuracy: 0.8286
# 2025-05-26 18:44:38.523 | INFO     | __main__:train_model:49 - Test Loss: 0.0826 Accuracy: 0.9006
# 2025-05-26 18:44:38.524 | INFO     | __main__:train_model:41 - Epoch 10/24
# 2025-05-26 18:45:17.758 | INFO     | __main__:train_model:45 - Train Loss: 0.1371 Accuracy: 0.8291
# 2025-05-26 18:45:20.644 | INFO     | __main__:train_model:49 - Test Loss: 0.0801 Accuracy: 0.9046
# 2025-05-26 18:45:20.645 | INFO     | __main__:train_model:41 - Epoch 11/24
# 2025-05-26 18:45:59.888 | INFO     | __main__:train_model:45 - Train Loss: 0.1356 Accuracy: 0.8307
# 2025-05-26 18:46:03.119 | INFO     | __main__:train_model:49 - Test Loss: 0.0816 Accuracy: 0.9000
# 2025-05-26 18:46:03.120 | INFO     | __main__:train_model:41 - Epoch 12/24
# 2025-05-26 18:46:42.071 | INFO     | __main__:train_model:45 - Train Loss: 0.1369 Accuracy: 0.8294
# 2025-05-26 18:46:45.805 | INFO     | __main__:train_model:49 - Test Loss: 0.0901 Accuracy: 0.8972
# 2025-05-26 18:46:45.806 | INFO     | __main__:train_model:41 - Epoch 13/24
# 2025-05-26 18:47:27.632 | INFO     | __main__:train_model:45 - Train Loss: 0.1366 Accuracy: 0.8309
# 2025-05-26 18:47:30.967 | INFO     | __main__:train_model:49 - Test Loss: 0.0901 Accuracy: 0.8950
# 2025-05-26 18:47:30.971 | INFO     | __main__:train_model:41 - Epoch 14/24
# 2025-05-26 18:48:10.086 | INFO     | __main__:train_model:45 - Train Loss: 0.1350 Accuracy: 0.8316
# 2025-05-26 18:48:13.209 | INFO     | __main__:train_model:49 - Test Loss: 0.0888 Accuracy: 0.8981
# 2025-05-26 18:48:13.210 | INFO     | __main__:train_model:41 - Epoch 15/24
# 2025-05-26 18:48:52.378 | INFO     | __main__:train_model:45 - Train Loss: 0.1356 Accuracy: 0.8309
# 2025-05-26 18:48:55.499 | INFO     | __main__:train_model:49 - Test Loss: 0.0956 Accuracy: 0.8906
# 2025-05-26 18:48:55.500 | INFO     | __main__:train_model:41 - Epoch 16/24
# 2025-05-26 18:49:34.272 | INFO     | __main__:train_model:45 - Train Loss: 0.1360 Accuracy: 0.8301
# 2025-05-26 18:49:37.163 | INFO     | __main__:train_model:49 - Test Loss: 0.0868 Accuracy: 0.9020
# 2025-05-26 18:49:37.164 | INFO     | __main__:train_model:41 - Epoch 17/24
# 2025-05-26 18:50:17.152 | INFO     | __main__:train_model:45 - Train Loss: 0.1372 Accuracy: 0.8272
# 2025-05-26 18:50:20.217 | INFO     | __main__:train_model:49 - Test Loss: 0.0867 Accuracy: 0.8956
# 2025-05-26 18:50:20.218 | INFO     | __main__:train_model:41 - Epoch 18/24
# 2025-05-26 18:50:59.316 | INFO     | __main__:train_model:45 - Train Loss: 0.1365 Accuracy: 0.8269
# 2025-05-26 18:51:02.416 | INFO     | __main__:train_model:49 - Test Loss: 0.0838 Accuracy: 0.9013
# 2025-05-26 18:51:02.416 | INFO     | __main__:train_model:41 - Epoch 19/24
# 2025-05-26 18:51:40.992 | INFO     | __main__:train_model:45 - Train Loss: 0.1351 Accuracy: 0.8307
# 2025-05-26 18:51:44.051 | INFO     | __main__:train_model:49 - Test Loss: 0.0770 Accuracy: 0.9106
# 2025-05-26 18:51:44.052 | INFO     | __main__:train_model:52 - New best accuracy: 0.9106, saving model
# 2025-05-26 18:51:44.079 | INFO     | __main__:train_model:41 - Epoch 20/24
# 2025-05-26 18:52:23.891 | INFO     | __main__:train_model:45 - Train Loss: 0.1369 Accuracy: 0.8294
# 2025-05-26 18:52:26.911 | INFO     | __main__:train_model:49 - Test Loss: 0.0897 Accuracy: 0.8870
# 2025-05-26 18:52:26.915 | INFO     | __main__:train_model:41 - Epoch 21/24
# 2025-05-26 18:53:07.114 | INFO     | __main__:train_model:45 - Train Loss: 0.1363 Accuracy: 0.8297
# 2025-05-26 18:53:10.899 | INFO     | __main__:train_model:49 - Test Loss: 0.0817 Accuracy: 0.9028
# 2025-05-26 18:53:10.900 | INFO     | __main__:train_model:41 - Epoch 22/24
# 2025-05-26 18:53:49.092 | INFO     | __main__:train_model:45 - Train Loss: 0.1357 Accuracy: 0.8344
# 2025-05-26 18:53:52.101 | INFO     | __main__:train_model:49 - Test Loss: 0.0796 Accuracy: 0.9030
# 2025-05-26 18:53:52.102 | INFO     | __main__:train_model:41 - Epoch 23/24
# 2025-05-26 18:54:30.585 | INFO     | __main__:train_model:45 - Train Loss: 0.1316 Accuracy: 0.8323
# 2025-05-26 18:54:33.537 | INFO     | __main__:train_model:49 - Test Loss: 0.0841 Accuracy: 0.9011
# 2025-05-26 18:54:33.538 | INFO     | __main__:train_model:41 - Epoch 24/24
# 2025-05-26 18:55:14.414 | INFO     | __main__:train_model:45 - Train Loss: 0.1358 Accuracy: 0.8312
# 2025-05-26 18:55:17.482 | INFO     | __main__:train_model:49 - Test Loss: 0.0893 Accuracy: 0.8959
# 2025-05-26 18:55:17.509 | SUCCESS  | __main__:<module>:14 - Done! layer ['layer1', 'conv1', 'bn1'] trained for 25 epochs in 0:17:47.50617265701294
